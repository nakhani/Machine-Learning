# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
female_data = pd.read_csv("ANSUR II FEMALE Public.csv")
female_data.columns = female_data.columns.str.lower().str.strip().str.replace(' ', '_')
female_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
male_data =pd.read_csv("ANSUR II MALE Public.csv", encoding= "latin1")
male_data.columns = male_data.columns.str.lower().str.strip().str.replace(' ', '_')
male_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
data = pd.concat([female_data,male_data])
data
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10037                             231            1282
# 1         10038                             194            1379
# 2         10042                             183            1369
# 3         10043                             261            1356
# 4         10051                             309            1303
# ...         ...                             ...             ...
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       301                 204          1180
# 1                       320                 207          1292
# ...

# %%
data.isnull().sum()
# Out:
# subjectid                         0
# abdominalextensiondepthsitting    0
# acromialheight                    0
# acromionradialelength             0
# anklecircumference                0
#                                  ..
# dodrace                           0
# age                               0
# heightin                          0
# weightlbs                         0
# writingpreference                 0
# Length: 108, dtype: int64

# %%
data["weightkg"]= data["weightkg"]/10
data["stature"] = data["stature"]/10
data["biacromialbreadth"] = data["biacromialbreadth"]/10
data["bideltoidbreadth"] = data["bideltoidbreadth"]/10


data["gender"] = data["gender"].replace(["Female", "Male"], [0,1]) 
men_data = data[data['gender'] == 0]
print(men_data.head())
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177               37.3
# 1                      225               178               37.2
# ...

# %%
women_data = data[data['gender'] == 0]  
men_data = data[data['gender'] == 1]    


fig = plt.figure(figsize=(8, 6))
fig.patch.set_facecolor('#2b2b2b')  
ax = plt.gca()
ax.set_facecolor('#2b2b2b')

plt.scatter(women_data['stature'], women_data['weightkg'], c='crimson', marker='o', label='Women', alpha=1.0)  
plt.scatter(men_data['stature'], men_data['weightkg'], c='royalblue', marker='o', label='Men', alpha=0.1)  

plt.title('Height vs Weight for Women and Men', fontsize=14, color='#e0e0e0')
plt.xlabel('Height (meters)', fontsize=12, color='#e0e0e0')
plt.ylabel('Weight (kg)', fontsize=12, color='#e0e0e0')

plt.xticks(fontsize=10, color='#e0e0e0')
plt.yticks(fontsize=10, color='#e0e0e0')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#e0e0e0')
ax.spines['bottom'].set_color('#e0e0e0')

plt.grid(color='#555555', linestyle='--', linewidth=0.5, alpha=0.6)

plt.legend(loc='upper left', fontsize=10, facecolor='#2b2b2b', edgecolor='#555555', framealpha=0.8)

plt.tight_layout()
plt.show()

# %%
print(data[['biacromialbreadth', 'bideltoidbreadth']].var())
print(data.groupby('gender')[['biacromialbreadth', 'bideltoidbreadth']].mean())
# Out:
# biacromialbreadth     9.142710
# bideltoidbreadth     17.754034
# dtype: float64
#         biacromialbreadth  bideltoidbreadth
# gender
# 0               36.534894         45.032427
# 1               41.567565         51.042479

# %%
from scipy.stats import ttest_ind
male_data = data[data['gender'] == 1]
female_data = data[data['gender'] == 0]
t_stat, p_val = ttest_ind(male_data['biacromialbreadth'], female_data['biacromialbreadth'])
t_stat_1, p_val_1 = ttest_ind(male_data['bideltoidbreadth'], female_data['bideltoidbreadth'])
print(f"t-statistic: {t_stat}, p-value: {p_val}")
print(f"t-statistic: {t_stat_1}, p-value: {p_val_1}")
# Out:
# t-statistic: 97.41274491427245, p-value: 0.0
# t-statistic: 70.16708848628309, p-value: 0.0

# %%
import seaborn as sns
sns.boxplot(x='gender', y='biacromialbreadth', data=data)
sns.boxplot(x='gender', y='bideltoidbreadth', data=data)
# Out:
# <Axes: xlabel='gender', ylabel='biacromialbreadth'>

# %%
women_data = data[data['gender'] == 0]  
men_data = data[data['gender'] == 1]    


fig = plt.figure(figsize=(8, 6))
fig.patch.set_facecolor('#2b2b2b') 
ax = plt.gca()
ax.set_facecolor('#2b2b2b')  


plt.scatter(women_data['biacromialbreadth'], women_data['bideltoidbreadth'], 
            c='crimson', marker='o', label='Women', alpha=1.0)  
plt.scatter(men_data['biacromialbreadth'], men_data['bideltoidbreadth'], 
            c='royalblue', marker='o', label='Men', alpha=0.1)  


plt.title('Biacromialbreadth vs Bideltoidbreadth by Gender', fontsize=14, color='#e0e0e0')
plt.xlabel('Biacromial Breadth', fontsize=12, color='#e0e0e0')
plt.ylabel('Bideltoid Breadth', fontsize=12, color='#e0e0e0')


plt.xticks(fontsize=10, color='#e0e0e0')
plt.yticks(fontsize=10, color='#e0e0e0')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#e0e0e0')
ax.spines['bottom'].set_color('#e0e0e0')


plt.grid(color='#555555', linestyle='--', linewidth=0.5, alpha=0.6)


plt.legend(loc='upper left', fontsize=10, facecolor='#2b2b2b', edgecolor='#555555', framealpha=0.8)


plt.tight_layout()
plt.show()

# %%
correlation = data[['gender', 'biacromialbreadth', 'bideltoidbreadth']].corr()
print(correlation['gender'].sort_values(ascending=False))
# Out:
# gender               1.000000
# biacromialbreadth    0.781047
# bideltoidbreadth     0.669339
# Name: gender, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = data[['biacromialbreadth', 'bideltoidbreadth', 'weightkg', 'stature']]
y = data['gender']


X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.2, random_state=42)

print(f"Training features shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Testing features shape: {X_test.shape}, Testing labels shape: {y_test.shape}")
# Out:
# Training features shape: (4854, 4), Training labels shape: (4854,)
# Testing features shape: (1214, 4), Testing labels shape: (1214,)

# %%
from knn import KNN

model = KNN(k=5)
model.fit(X_train, y_train)
accuracy = model.evaluate(X_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 93.08%

# %%
from knn import KNN

model = KNN(k=3)
model.fit(X_train, y_train)
accuracy = model.evaluate(X_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 92.34%

# %%
from knn import KNN

model = KNN(k=7)
model.fit(X_train, y_train)
accuracy = model.evaluate(X_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 93.00%

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
conff_matrix = np.zeros((2, 2), dtype=int)


for i in range(len(y_test)):  
    if y_test[i] == 0 and y_pred[i] == 0:
        conff_matrix[0][0] += 1  # (TN)
    elif y_test[i] == 0 and y_pred[i] == 1:
        conff_matrix[0][1] += 1  # (FP)
    elif y_test[i] == 1 and y_pred[i] == 0:
        conff_matrix[1][0] += 1  # (FN)
    elif y_test[i] == 1 and y_pred[i] == 1:
        conff_matrix[1][1] += 1  # (TP)


print("Confusion Matrix:")
print(conff_matrix)
# Out:
# Confusion Matrix:
# [[380  46]
#  [ 38 750]]

# %%
from sklearn import metrics



cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=conff_matrix, display_labels=[0, 1])

fig = plt.figure(figsize=(8, 6))
fig.patch.set_facecolor('#2b2b2b') 
ax = plt.gca()
ax.set_facecolor('#2b2b2b')  

cm_display.plot(ax=ax, cmap='plasma') 
plt.title('Confusion Matrix', fontsize=14, color='#e0e0e0')  
plt.xlabel('Predicted Labels', fontsize=12, color='#e0e0e0')
plt.ylabel('Actual Labels', fontsize=12, color='#e0e0e0')


plt.xticks(fontsize=10, color='#e0e0e0')
plt.yticks(fontsize=10, color='#e0e0e0')


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#e0e0e0')
ax.spines['bottom'].set_color('#e0e0e0')
plt.grid(color='#555555', linestyle='--', linewidth=0.5, alpha=0.6)


plt.tight_layout()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

knn_model = KNeighborsClassifier(n_neighbors=5)  


knn_model.fit(X_train, y_train)


y_pred = knn_model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print(f"Scikit-learn KNN Model Accuracy: {accuracy * 100:.2f}%")


conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Scikit-learn KNN Model Accuracy: 93.08%
# Confusion Matrix:
# [[380  46]
#  [ 38 750]]

# %%
from sklearn import metrics

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[0, 1])

fig = plt.figure(figsize=(8, 6))
fig.patch.set_facecolor('#2b2b2b') 
ax = plt.gca()
ax.set_facecolor('#2b2b2b')  

cm_display.plot(ax=ax, cmap='plasma')
plt.title('Confusion Matrix', fontsize=14, color='#e0e0e0') 
plt.xlabel('Predicted Labels', fontsize=12, color='#e0e0e0')
plt.ylabel('Actual Labels', fontsize=12, color='#e0e0e0')


plt.xticks(fontsize=10, color='#e0e0e0')
plt.yticks(fontsize=10, color='#e0e0e0')


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#e0e0e0')
ax.spines['bottom'].set_color('#e0e0e0')
plt.grid(color='#555555', linestyle='--', linewidth=0.5, alpha=0.6)


plt.tight_layout()
plt.show()
